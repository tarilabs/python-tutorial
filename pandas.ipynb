# %%
dict = {"country": ["Brazil", "Russia", "India", "China", "South Africa"],
       "capital": ["Brasilia", "Moscow", "New Dehli", "Beijing", "Pretoria"],
       "area": [8.516, 17.10, 3.286, 9.597, 1.221],
       "population": [200.4, 143.5, 1252, 1357, 52.98] }

import pandas as pd
brics = pd.DataFrame(dict)
print(brics)
# Out:
# country    capital  area  population
# 0        Brazil   Brasilia   8.5       200.4
# 1        Russia     Moscow  17.1       143.5
# 2         India  New Dehli   3.3      1252.0
# 3         China    Beijing   9.6      1357.0
# 4  South Africa   Pretoria   1.2        53.0

# %%
# Set the index for brics
brics.index = ["BR", "RU", "IN", "CH", "SA"]

# Print out brics with new index values
print(brics)
# Out:
# country    capital  area  population
# BR        Brazil   Brasilia   8.5       200.4
# RU        Russia     Moscow  17.1       143.5
# IN         India  New Dehli   3.3      1252.0
# CH         China    Beijing   9.6      1357.0
# SA  South Africa   Pretoria   1.2        53.0

# %%
brics = pd.DataFrame(dict, index=dict['country'])
brics
# Out:
#                    country    capital  area  population
# Brazil              Brazil   Brasilia   8.5       200.4
# Russia              Russia     Moscow  17.1       143.5
# India                India  New Dehli   3.3      1252.0
# China                China    Beijing   9.6      1357.0
# South Africa  South Africa   Pretoria   1.2        53.0

# %%
print(brics['population'])
# Out:
# Brazil           200.4
# Russia           143.5
# India           1252.0
# China           1357.0
# South Africa      53.0
# Name: population, dtype: float64

# %%
print(brics[['population']])
# Out:
# population
# Brazil             200.4
# Russia             143.5
# India             1252.0
# China             1357.0
# South Africa        53.0

# %%
brics[['population']]
# Out:
#               population
# Brazil             200.4
# Russia             143.5
# India             1252.0
# China             1357.0
# South Africa        53.0

# %%
print(brics[['capital', 'population']])
brics[['capital', 'population']]
# Out:
# capital  population
# Brazil         Brasilia       200.4
# Russia           Moscow       143.5
# India         New Dehli      1252.0
# China           Beijing      1357.0
# South Africa   Pretoria        53.0
#                 capital  population
# Brazil         Brasilia       200.4
# Russia           Moscow       143.5
# India         New Dehli      1252.0
# China           Beijing      1357.0
# South Africa   Pretoria        53.0

# %%
print(brics[0:1])
# Out:
# country   capital  area  population
# Brazil  Brazil  Brasilia   8.5       200.4

# %%
print(brics[2:20])
# Out:
# country    capital  area  population
# India                India  New Dehli   3.3      1252.0
# China                China    Beijing   9.6      1357.0
# South Africa  South Africa   Pretoria   1.2        53.0

# %%
print(brics.iloc[0])
brics.iloc[0]
# Out:
# country         Brazil
# capital       Brasilia
# area                 9
# population       2e+02
# Name: Brazil, dtype: object
# country         Brazil
# capital       Brasilia
# area                 9
# population       2e+02
# Name: Brazil, dtype: object

# %%
brics.loc[['Brazil']]
# Out:
#        country   capital  area  population
# Brazil  Brazil  Brasilia   8.5       200.4

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 

# %matplotlib inline

# %%
titanic_df = pd.read_excel('http://biostat.mc.vanderbilt.edu/wiki/pub/Main/DataSets/titanic3.xls', 'titanic3', index_col=None, na_values=['NA'])

# %%
titanic_df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#     age  sibsp  parch  ticket   fare    cabin embarked boat   body  \
# 0  29.0      0      0   24160  211.3       B5        S    2    NaN
# 1   0.9      1      2  113781  151.6  C22 C26        S   11    NaN
# 2   2.0      1      2  113781  151.6  C22 C26        S  NaN    NaN
# 3  30.0      1      2  113781  151.6  C22 C26        S  NaN  135.0
# 4  25.0      1      2  113781  151.6  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %%
titanic_df.describe()
# Out:
#        pclass  survived     age   sibsp   parch    fare   body
# count  1309.0    1309.0  1046.0  1309.0  1309.0  1308.0  121.0
# mean      2.3       0.4    29.9     0.5     0.4    33.3  160.8
# std       0.8       0.5    14.4     1.0     0.9    51.8   97.7
# min       1.0       0.0     0.2     0.0     0.0     0.0    1.0
# 25%       2.0       0.0    21.0     0.0     0.0     7.9   72.0
# 50%       3.0       0.0    28.0     0.0     0.0    14.5  155.0
# 75%       3.0       1.0    39.0     1.0     0.0    31.3  256.0
# max       3.0       1.0    80.0     8.0     9.0   512.3  328.0

# %%
titanic_df.drop(['ticket', 'cabin', 'boat', 'body'], axis=1).head() # I believe here the tutorial meant to reassign the variable?!
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#     age  sibsp  parch   fare embarked                        home.dest
# 0  29.0      0      0  211.3        S                     St Louis, MO
# 1   0.9      1      2  151.6        S  Montreal, PQ / Chesterville, ON
# 2   2.0      1      2  151.6        S  Montreal, PQ / Chesterville, ON
# 3  30.0      1      2  151.6        S  Montreal, PQ / Chesterville, ON
# 4  25.0      1      2  151.6        S  Montreal, PQ / Chesterville, ON

# %%
titanic_df.isnull()
# Out:
#       pclass  survived   name    sex    age  sibsp  parch  ticket   fare  \
# 0      False     False  False  False  False  False  False   False  False
# 1      False     False  False  False  False  False  False   False  False
# 2      False     False  False  False  False  False  False   False  False
# 3      False     False  False  False  False  False  False   False  False
# 4      False     False  False  False  False  False  False   False  False
# ...      ...       ...    ...    ...    ...    ...    ...     ...    ...
# 1304   False     False  False  False  False  False  False   False  False
# 1305   False     False  False  False   True  False  False   False  False
# 1306   False     False  False  False  False  False  False   False  False
# 1307   False     False  False  False  False  False  False   False  False
# 1308   False     False  False  False  False  False  False   False  False
#
#       cabin  embarked   boat   body  home.dest
# ...

# %%
titanic_df.isnull().sum()
# Out:
# pclass          0
# survived        0
# name            0
# sex             0
# age           263
# sibsp           0
# parch           0
# ticket          0
# fare            1
# cabin        1014
# embarked        2
# boat          823
# body         1188
# home.dest     564
# dtype: int64

# %%
pd.value_counts(titanic_df['survived']).plot.bar()

# %%
titanic_df['survived'].mean()
# Out:
# 0.3819709702062643

# %%
titanic_df.groupby(['sex']).mean()
# Out:
#         pclass  survived   age  sibsp  parch  fare   body
# sex
# female     2.2       0.7  28.7    0.7    0.6  46.2  166.6
# male       2.4       0.2  30.6    0.4    0.2  26.2  160.4

# %%
titanic_df.groupby(['sex', 'pclass']).mean()
# Out:
#                survived   age  sibsp  parch   fare   body
# sex    pclass
# female 1            1.0  37.0    0.6    0.5  109.4    NaN
#        2            0.9  27.5    0.5    0.7   23.2   52.0
#        3            0.5  22.2    0.8    0.7   15.3  183.0
# male   1            0.3  41.0    0.3    0.3   69.9  162.8
#        2            0.1  30.8    0.3    0.2   19.9  171.2
#        3            0.2  26.0    0.5    0.3   12.4  151.9

# %%
titanic_df[titanic_df['age']<18].groupby(['sex', 'pclass']).mean()
# Out:
#                survived   age  sibsp  parch   fare   body
# sex    pclass
# female 1            0.9  14.1    0.5    0.9  104.1    NaN
#        2            1.0   8.3    0.7    1.2   28.0    NaN
#        3            0.5   8.4    1.5    1.0   18.3  328.0
# male   1            0.9   9.8    0.6    1.7  129.8    NaN
#        2            0.7   6.2    0.6    0.9   31.8    NaN
#        3            0.2   9.8    2.0    1.0   21.7   65.5

# %%
import quandl

# %%
quandl.ApiConfig.api_key = ''
apple = quandl.get('WIKI/AAPL')
ms = quandl.get('WIKI/MSFT')

# %%
ms.head()
# Out:
#             Open  High   Low  Close   Volume  Ex-Dividend  Split Ratio  \
# Date
# 1986-03-13  25.5  29.2  25.5   28.0  3.6e+06          0.0          1.0
# 1986-03-14  28.0  29.5  28.0   29.0  1.1e+06          0.0          1.0
# 1986-03-17  29.0  29.8  29.0   29.5  4.6e+05          0.0          1.0
# 1986-03-18  29.5  29.8  28.5   28.8  2.4e+05          0.0          1.0
# 1986-03-19  28.8  29.0  28.0   28.2  1.7e+05          0.0          1.0
#
#             Adj. Open  Adj. High  Adj. Low  Adj. Close  Adj. Volume
# Date
# 1986-03-13    5.9e-02    6.8e-02   5.9e-02     6.5e-02      1.0e+09
# 1986-03-14    6.5e-02    6.8e-02   6.5e-02     6.7e-02      3.1e+08
# 1986-03-17    6.7e-02    6.9e-02   6.7e-02     6.8e-02      1.3e+08
# 1986-03-18    6.8e-02    6.9e-02   6.6e-02     6.6e-02      6.8e+07
# 1986-03-19    6.6e-02    6.7e-02   6.5e-02     6.5e-02      4.8e+07

# %%
ms['Adj. Close'].plot()

# %%
ms.index
# Out:
# DatetimeIndex(['1986-03-13', '1986-03-14', '1986-03-17', '1986-03-18',
#                '1986-03-19', '1986-03-20', '1986-03-21', '1986-03-24',
#                '1986-03-25', '1986-03-26',
#                ...
#                '2018-03-14', '2018-03-15', '2018-03-16', '2018-03-19',
#                '2018-03-20', '2018-03-21', '2018-03-22', '2018-03-23',
#                '2018-03-26', '2018-03-27'],
#               dtype='datetime64[ns]', name='Date', length=8076, freq=None)

# %%
ms['2018']['Adj. Close'].plot()

# %%
ms['2018-03']['Adj. Close'].plot()

# %%
ms.loc['2018-01-01':'2018-03-31']['Adj. Close'].plot()

# %%
ms_price = ms[['Adj. Close']]
apple_price = apple[['Adj. Close']]

# %%
ms_price
# Out:
#             Adj. Close
# Date
# 1986-03-13     6.5e-02
# 1986-03-14     6.7e-02
# 1986-03-17     6.8e-02
# 1986-03-18     6.6e-02
# 1986-03-19     6.5e-02
# ...                ...
# 2018-03-21     9.2e+01
# 2018-03-22     9.0e+01
# 2018-03-23     8.7e+01
# 2018-03-26     9.4e+01
# 2018-03-27     8.9e+01
#
# [8076 rows x 1 columns]

# %%
ms_price.rename(columns={'Adj. Close' : 'MSFT'}, inplace=True)
apple_price.rename(columns={'Adj. Close' : 'AAPL'}, inplace=True)

# %%
ms_price
# Out:
#                MSFT
# Date
# 1986-03-13  6.5e-02
# 1986-03-14  6.7e-02
# 1986-03-17  6.8e-02
# 1986-03-18  6.6e-02
# 1986-03-19  6.5e-02
# ...             ...
# 2018-03-21  9.2e+01
# 2018-03-22  9.0e+01
# 2018-03-23  8.7e+01
# 2018-03-26  9.4e+01
# 2018-03-27  8.9e+01
#
# [8076 rows x 1 columns]

# %%
both_stocks = ms_price.join(apple_price, how='inner')

# %%
both_stocks
# Out:
#                MSFT   AAPL
# Date
# 1986-03-13  6.5e-02    0.4
# 1986-03-14  6.7e-02    0.4
# 1986-03-17  6.8e-02    0.4
# 1986-03-18  6.6e-02    0.4
# 1986-03-19  6.5e-02    0.4
# ...             ...    ...
# 2018-03-21  9.2e+01  171.3
# 2018-03-22  9.0e+01  168.8
# 2018-03-23  8.7e+01  164.9
# 2018-03-26  9.4e+01  172.8
# 2018-03-27  8.9e+01  168.3
#
# [8075 rows x 2 columns]

# %%
both_stocks.plot()

# %%
both_stocks.loc['2017'].plot()

# %%
both_stocks['2017'].rolling(min_periods=10, window=60, center=False).mean().plot()

# %%
both_stocks['2017'].rolling(min_periods=10, window=60, center=False).std().plot()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import requests

# %%
s = pd.Series(np.random.randn(4), name='daily returns')
s
# Out:
# 0   -0.4
# 1    0.5
# 2   -0.9
# 3   -0.4
# Name: daily returns, dtype: float64

# %%
s * 100
# Out:
# 0   -44.1
# 1    53.5
# 2   -93.0
# 3   -42.0
# Name: daily returns, dtype: float64

# %%
np.abs(s)
# Out:
# 0    0.4
# 1    0.5
# 2    0.9
# 3    0.4
# Name: daily returns, dtype: float64

# %%
s.describe()
# Out:
# count    4.0
# mean    -0.3
# std      0.6
# min     -0.9
# 25%     -0.6
# 50%     -0.4
# 75%     -0.2
# max      0.5
# Name: daily returns, dtype: float64

# %%
s.index = ['AMZN', 'AAPL', 'MSFT', 'GOOG']
s
# Out:
# AMZN   -0.4
# AAPL    0.5
# MSFT   -0.9
# GOOG   -0.4
# Name: daily returns, dtype: float64

# %%
s['AMZN']
# Out:
# -0.44139933672564985

# %%
s['AMZN'] = 0
s
# Out:
# AMZN    0.0
# AAPL    0.5
# MSFT   -0.9
# GOOG   -0.4
# Name: daily returns, dtype: float64

# %%
'AAPL' in s
# Out:
# True

# %%
df = pd.read_csv('https://github.com/QuantEcon/QuantEcon.lectures.code/raw/master/pandas/data/test_pwt.csv')
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#      country country isocode  year      POP  XRAT    tcgdp    cc    cg
# 0  Argentina             ARG  2000  3.7e+04   1.0  3.0e+05  75.7   5.6
# 1  Australia             AUS  2000  1.9e+04   1.7  5.4e+05  67.8   6.7
# 2      India             IND  2000  1.0e+06  44.9  1.7e+06  64.6  14.1
# 3     Israel             ISR  2000  6.1e+03   4.1  1.3e+05  64.4  10.3
# 4     Malawi             MWI  2000  1.2e+04  59.5  5.0e+03  74.7  11.7

# %%
df[2:5]
# Out:
#   country country isocode  year      POP  XRAT    tcgdp    cc    cg
# 2   India             IND  2000  1.0e+06  44.9  1.7e+06  64.6  14.1
# 3  Israel             ISR  2000  6.1e+03   4.1  1.3e+05  64.4  10.3
# 4  Malawi             MWI  2000  1.2e+04  59.5  5.0e+03  74.7  11.7

# %%
df[['country','tcgdp']]
# Out:
#          country    tcgdp
# 0      Argentina  3.0e+05
# 1      Australia  5.4e+05
# 2          India  1.7e+06
# 3         Israel  1.3e+05
# 4         Malawi  5.0e+03
# 5   South Africa  2.3e+05
# 6  United States  9.9e+06
# 7        Uruguay  2.5e+04

# %%
df.iloc[2:5, 0:4]
# Out:
#   country country isocode  year      POP
# 2   India             IND  2000  1.0e+06
# 3  Israel             ISR  2000  6.1e+03
# 4  Malawi             MWI  2000  1.2e+04

# %%
df.loc[df.index[2:5], ['country', 'tcgdp']]
# Out:
#   country    tcgdp
# 2   India  1.7e+06
# 3  Israel  1.3e+05
# 4  Malawi  5.0e+03

# %%
df = df[['country', 'POP', 'tcgdp']]
df
# Out:
#          country      POP    tcgdp
# 0      Argentina  3.7e+04  3.0e+05
# 1      Australia  1.9e+04  5.4e+05
# 2          India  1.0e+06  1.7e+06
# 3         Israel  6.1e+03  1.3e+05
# 4         Malawi  1.2e+04  5.0e+03
# 5   South Africa  4.5e+04  2.3e+05
# 6  United States  2.8e+05  9.9e+06
# 7        Uruguay  3.2e+03  2.5e+04

# %%
df = df.set_index('country')
df
# Out:
#                    POP    tcgdp
# country
# Argentina      3.7e+04  3.0e+05
# Australia      1.9e+04  5.4e+05
# India          1.0e+06  1.7e+06
# Israel         6.1e+03  1.3e+05
# Malawi         1.2e+04  5.0e+03
# South Africa   4.5e+04  2.3e+05
# United States  2.8e+05  9.9e+06
# Uruguay        3.2e+03  2.5e+04

# %%
df.columns = 'population', 'total GDP'
df
# Out:
#                population  total GDP
# country
# Argentina         3.7e+04    3.0e+05
# Australia         1.9e+04    5.4e+05
# India             1.0e+06    1.7e+06
# Israel            6.1e+03    1.3e+05
# Malawi            1.2e+04    5.0e+03
# South Africa      4.5e+04    2.3e+05
# United States     2.8e+05    9.9e+06
# Uruguay           3.2e+03    2.5e+04

# %%
df['population'] = df['population'] * 1e3
df
# Out:
#                population  total GDP
# country
# Argentina         3.7e+07    3.0e+05
# Australia         1.9e+07    5.4e+05
# India             1.0e+09    1.7e+06
# Israel            6.1e+06    1.3e+05
# Malawi            1.2e+07    5.0e+03
# South Africa      4.5e+07    2.3e+05
# United States     2.8e+08    9.9e+06
# Uruguay           3.2e+06    2.5e+04

# %%
df['GDP percap'] = df['total GDP'] * 1e6 / df['population']
df
# Out:
#                population  total GDP  GDP percap
# country
# Argentina         3.7e+07    3.0e+05      7903.2
# Australia         1.9e+07    5.4e+05     28436.4
# India             1.0e+09    1.7e+06      1717.3
# Israel            6.1e+06    1.3e+05     21138.7
# Malawi            1.2e+07    5.0e+03       425.9
# South Africa      4.5e+07    2.3e+05      5042.6
# United States     2.8e+08    9.9e+06     35080.4
# Uruguay           3.2e+06    2.5e+04      7844.0

# %%
df['GDP percap'].plot(kind='bar')
plt.show()

# %%
df = df.sort_values(by='GDP percap', ascending=False)
df
# Out:
#                population  total GDP  GDP percap
# country
# United States     2.8e+08    9.9e+06     35080.4
# Australia         1.9e+07    5.4e+05     28436.4
# Israel            6.1e+06    1.3e+05     21138.7
# Argentina         3.7e+07    3.0e+05      7903.2
# Uruguay           3.2e+06    2.5e+04      7844.0
# South Africa      4.5e+07    2.3e+05      5042.6
# India             1.0e+09    1.7e+06      1717.3
# Malawi            1.2e+07    5.0e+03       425.9

# %%
df['GDP percap'].plot(kind='bar')
plt.show()

# %%
r = requests.get('http://research.stlouisfed.org/fred2/series/UNRATE/downloaddata/UNRATE.csv')

# %%
url = 'http://research.stlouisfed.org/fred2/series/UNRATE/downloaddata/UNRATE.csv'
source = requests.get(url).content.decode().split("\n")
source[0]
# Out:
# 'DATE,VALUE\r'

# %%
source[1]
# Out:
# '1948-01-01,3.4\r'

# %%
source[2]
# Out:
# '1948-02-01,3.8\r'

# %%
data = pd.read_csv(url, index_col=0, parse_dates=True)

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.head()
# Out:
#             VALUE
# DATE
# 1948-01-01    3.4
# 1948-02-01    3.8
# 1948-03-01    4.0
# 1948-04-01    3.9
# 1948-05-01    3.5

# %%
pd.set_option('precision', 1)
data.describe()  # Your output might differ slightly
# Out:
#        VALUE
# count  863.0
# mean     5.7
# std      1.6
# min      2.5
# 25%      4.5
# 50%      5.6
# 75%      6.8
# max     10.8

# %%
data['2006':'2012'].plot()
plt.show()

# %%
from pandas_datareader import wb

govt_debt = wb.download(indicator='GC.DOD.TOTL.GD.ZS', country=['US', 'AU'], start=2005, end=2016).stack().unstack(0)
ind = govt_debt.index.droplevel(-1)
govt_debt.index = ind
ax = govt_debt.plot(lw=2)
plt.title("Government Debt to GDP (%)")
plt.show()

# %%
ticker_list = {'INTC': 'Intel',
               'MSFT': 'Microsoft',
               'IBM': 'IBM',
               'BHP': 'BHP',
               'TM': 'Toyota',
               'AAPL': 'Apple',
               'AMZN': 'Amazon',
               'BA': 'Boeing',
               'QCOM': 'Qualcomm',
               'KO': 'Coca-Cola',
               'GOOG': 'Google',
               'SNE': 'Sony',
               'PTR': 'PetroChina'}

# %%
df = pd.read_csv('https://python.quantecon.org/_static/lecture_specific/pandas/data/ticker_data.csv', index_col=0, parse_dates=True)
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#             INTC  MSFT    IBM   BHP    TM   AAPL   AMZN    BA  QCOM    KO  \
# Date
# 2013-01-02  21.4  27.6  196.4  79.9  96.0  549.0  257.3  77.1  64.8  37.6
# 2013-01-03  21.3  27.2  195.3  79.0  95.4  542.1  258.5  77.5  64.4  37.6
# 2013-01-04  21.2  26.7  194.0  79.4  97.3  527.0  259.1  77.7  63.5  37.7
# 2013-01-07  21.2  26.7  193.1  79.7  95.5  523.9  268.5  76.1  64.0  37.3
# 2013-01-08  21.1  26.5  192.9  78.5  93.9  525.3  266.4  74.1  63.9  37.0
#
#              GOOG   SNE    PTR
# Date
# 2013-01-02  723.3  11.5  145.8
# 2013-01-03  723.7  11.5  145.8
# 2013-01-04  738.0  11.1  145.6
# 2013-01-07  734.8  11.0  142.9
# 2013-01-08  733.3  10.7  141.3

# %%
df.tail()
# Out:
#             INTC  MSFT    IBM   BHP     TM   AAPL   AMZN     BA  QCOM    KO  \
# Date
# 2013-12-24  25.4  37.1  183.2  67.1  118.6  567.7  399.2  136.8  73.0  40.2
# 2013-12-26  25.7  37.4  185.4  66.8  121.7  563.9  404.4  138.3  73.5  40.5
# 2013-12-27  25.6  37.3  185.1  67.4  121.9  560.1  398.1  136.9  73.8  40.7
# 2013-12-30  25.9  37.3  186.4  67.7  121.4  554.5  393.4  135.9  73.6  41.1
# 2013-12-31  26.0  37.4  187.6  68.2  121.9  561.0  398.8  136.5  74.2  41.3
#
#               GOOG   SNE    PTR
# Date
# 2013-12-24  1111.8  17.5  109.7
# 2013-12-26  1117.5  17.3  109.5
# 2013-12-27  1118.4  17.1  110.0
# 2013-12-30  1109.5  17.5  109.7
# 2013-12-31  1120.7  17.3  109.7

# %%
((df.tail(1).values - df.head(1).values) / df.head(1).values) * 100
# Out:
# array([[ 21.42189062,  35.44532457,  -4.47160618, -14.67534468,
#          27.01323111,   2.18385544,  54.98426493,  77.09874789,
#          14.67181467,   9.86702978,  54.95472521,  50.21721112,
#         -24.72734531]])

# %%
x = pd.Series((((df.tail(1).values - df.head(1).values) / df.head(1).values) * 100)[0], name='Price change')

# %%
x
# Out:
# 0     21.4
# 1     35.4
# 2     -4.5
# 3    -14.7
# 4     27.0
# 5      2.2
# 6     55.0
# 7     77.1
# 8     14.7
# 9      9.9
# 10    55.0
# 11    50.2
# 12   -24.7
# Name: Price change, dtype: float64

# %%
x.index = ticker_list.values()
x
# Out:
# Intel         21.4
# Microsoft     35.4
# IBM           -4.5
# BHP          -14.7
# Toyota        27.0
# Apple          2.2
# Amazon        55.0
# Boeing        77.1
# Qualcomm      14.7
# Coca-Cola      9.9
# Google        55.0
# Sony          50.2
# PetroChina   -24.7
# Name: Price change, dtype: float64

# %%
x = x.sort_values()
x.plot(kind='bar')
plt.show()

# %%
# offical solution was:
ticker = pd.read_csv('https://github.com/QuantEcon/QuantEcon.lectures.code/raw/master/pandas/data/ticker_data.csv')
ticker.set_index('Date', inplace=True)

ticker_list = {'INTC': 'Intel',
               'MSFT': 'Microsoft',
               'IBM': 'IBM',
               'BHP': 'BHP',
               'TM': 'Toyota',
               'AAPL': 'Apple',
               'AMZN': 'Amazon',
               'BA': 'Boeing',
               'QCOM': 'Qualcomm',
               'KO': 'Coca-Cola',
               'GOOG': 'Google',
               'SNE': 'Sony',
               'PTR': 'PetroChina'}

price_change = pd.Series()

for tick in ticker_list:
    change = 100 * (ticker.loc[ticker.index[-1], tick] - ticker.loc[ticker.index[0], tick]) / ticker.loc[ticker.index[0], tick]
    name = ticker_list[tick]
    price_change[name] = change

price_change.sort_values(inplace=True)
fig, ax = plt.subplots(figsize=(10,8))
price_change.plot(kind='bar', ax=ax)
plt.show()
